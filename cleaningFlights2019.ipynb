# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("05-2019.csv")
df2 = pd.read_csv("06-2019.csv")
df3 = pd.read_csv("07-2019.csv")
df4 = pd.read_csv("08-2019.csv")
df5 = pd.read_csv("09-2019.csv")
df6 = pd.read_csv("10-2019.csv")
df7 = pd.read_csv("11-2019.csv")
df8 = pd.read_csv("12-2019.csv")

# %%
concat_df = pd.concat([df1, df2])
concat_df = pd.concat([concat_df, df3])
concat_df = pd.concat([concat_df, df4])
concat_df = pd.concat([concat_df, df5])
concat_df = pd.concat([concat_df, df6])
concat_df = pd.concat([concat_df, df7])
concat_df = pd.concat([concat_df, df8])
concat_df.head()
# Out:
#   carrier_code  flight_number origin_airport destination_airport        date  \
# 0           AS            121            SEA                 ANC  2019-05-01
# 1           F9            402            LAX                 DEN  2019-05-01
# 2           F9            662            SFO                 DEN  2019-05-01
# 3           F9            790            PDX                 DEN  2019-05-01
# 4           AS            108            ANC                 SEA  2019-05-01
#
#    scheduled_elapsed_time tail_number  departure_delay  arrival_delay  \
# 0                     215      N615AS               -8            -16
# 1                     147      N701FR               17             -4
# 2                     158      N346FR               44             27
# 3                     156      N332FR               24             10
# 4                     210      N548AS               -9            -31
#
#    delay_carrier  ...  HourlyPrecipitation_x  HourlyStationPressure_x  \
# ...

# %%
concat_df.shape
# Out:
# (5512903, 35)

# %%
concat_df.dtypes
# Out:
# carrier_code                       object
# flight_number                       int64
# origin_airport                     object
# destination_airport                object
# date                               object
# scheduled_elapsed_time              int64
# tail_number                        object
# departure_delay                     int64
# arrival_delay                       int64
# delay_carrier                       int64
# delay_weather                       int64
# delay_national_aviation_system      int64
# delay_security                      int64
# delay_late_aircarft_arrival         int64
# cancelled_code                     object
# year                                int64
# month                               int64
# day                                 int64
# weekday                             int64
# scheduled_departure_dt             object
# scheduled_arrival_dt               object
# actual_departure_dt                object
# ...

# %%
# Out:
# array(['N', 'B', 'A', 'C', 'D'], dtype=object)

# %% [markdown]
# Unnecessary columns
# * Carrier_code
# * flight_number
# * scheduled_elapsed_time
# * tail_number
# * weekday
# * scheculed_departure_dt (redundant, using departure_delay)
# * scheduled_arrival_dt (redundant, using arrival delay)
# * actual_departure_dt (redundant, using departure_delay)
# * actual_arrival_dt (redundant, using departure_delay)
# * STATION_X
# * STATION_Y
